# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# #### Mert Ozkaya
# Mechanical Engineer

# %% [markdown]
# ##### I want to be data scientist because I believe that everything will be rely on data. Also, I love math.

# %% [markdown]
# ### Below code will add 2 to 3.

# %%
2+3
# Out:
# 5

# %% [markdown]
# Bulleted List:
#
# - item 1
# - item 2
# - item 3
#
# Numbered List:
#
# 1. First item
# 2. Second item
# 3. Third item
#
# Blocked Quotes
# > "Block quote example"
